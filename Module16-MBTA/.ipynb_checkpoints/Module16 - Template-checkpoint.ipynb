# %% [markdown]
# <h1>Module 16 Project Template</h1>

# %% [markdown]
# Use the code below to help you analyze the data returned by the MBTA API:

# %%
mbtaURL = "https://api-v3.mbta.com/vehicles?filter[route]=1&include=trip"

import urllib.request, json
with urllib.request.urlopen(mbtaURL) as url:
    data = json.loads(url.read().decode())
   
    with open('data.json', 'w') as outfile:
        json.dump(data, outfile)
   
    with open('data.txt', 'w') as outfile:
        json.dump(json.dumps(data, indent=4, sort_keys=True), outfile)
       
    print(json.dumps(data, indent=4, sort_keys=True))
# Out:
# {
#     "data": [
#         {
#             "attributes": {
#                 "bearing": 285,
#                 "carriages": [],
#                 "current_status": "STOPPED_AT",
#                 "current_stop_sequence": 1,
#                 "direction_id": 0,
#                 "label": "1877",
#                 "latitude": 42.34268173,
#                 "longitude": -71.06144459,
#                 "occupancy_status": "MANY_SEATS_AVAILABLE",
#                 "revenue": "REVENUE",
#                 "speed": null,
#                 "updated_at": "2024-09-14T06:45:32-04:00"
#             },
#             "id": "y1877",
#             "links": {
#                 "self": "/vehicles/y1877"
#             },
#             "relationships": {
#                 "route": {
#                     "data": {
#                         "id": "1",
#                         "type": "route"
#                     }
#                 },
#                 "stop": {
#                     "data": {
#                         "id": "64",
#                         "type": "stop"
#                     }
#                 },
#                 "trip": {
#                     "data": {
#                         "id": "64387626",
#                         "type": "trip"
#                     }
#                 }
#             },
#             "type": "vehicle"
#         },
#         {
#             "attributes": {
#                 "bearing": 135,
#                 "carriages": [],
#                 "current_status": "IN_TRANSIT_TO",
#                 "current_stop_sequence": 18,
#                 "direction_id": 1,
#                 "label": "1872",
#                 "latitude": 42.33548651,
#                 "longitude": -71.07578861,
#                 "occupancy_status": "FEW_SEATS_AVAILABLE",
#                 "revenue": "REVENUE",
#                 "speed": null,
#                 "updated_at": "2024-09-14T06:45:33-04:00"
#             },
#             "id": "y1872",
#             "links": {
#                 "self": "/vehicles/y1872"
#             },
#             "relationships": {
#                 "route": {
#                     "data": {
#                         "id": "1",
#                         "type": "route"
#                     }
#                 },
#                 "stop": {
#                     "data": {
#                         "id": "854",
#                         "type": "stop"
#                     }
#                 },
#                 "trip": {
#                     "data": {
#                         "id": "64387714",
#                         "type": "trip"
#                     }
#                 }
#             },
#             "type": "vehicle"
#         },
#         {
#             "attributes": {
#                 "bearing": 159,
#                 "carriages": [],
#                 "current_status": "STOPPED_AT",
#                 "current_stop_sequence": 10,
#                 "direction_id": 1,
#                 "label": "1831",
#                 "latitude": 42.35815522,
#                 "longitude": -71.09305947,
#                 "occupancy_status": "MANY_SEATS_AVAILABLE",
#                 "revenue": "REVENUE",
#                 "speed": null,
#                 "updated_at": "2024-09-14T06:45:30-04:00"
#             },
#             "id": "y1831",
#             "links": {
#                 "self": "/vehicles/y1831"
#             },
#             "relationships": {
#                 "route": {
#                     "data": {
#                         "id": "1",
#                         "type": "route"
#                     }
#                 },
#                 "stop": {
#                     "data": {
#                         "id": "75",
#                         "type": "stop"
#                     }
#                 },
#                 "trip": {
#                     "data": {
#                         "id": "64387718",
#                         "type": "trip"
#                     }
#                 }
#             },
#             "type": "vehicle"
#         },
#         {
#             "attributes": {
#                 "bearing": 0,
#                 "carriages": [],
#                 "current_status": "IN_TRANSIT_TO",
#                 "current_stop_sequence": 14,
#                 "direction_id": 0,
#                 "label": "1823",
#                 "latitude": 42.34972217,
#                 "longitude": -71.08878727,
#                 "occupancy_status": "MANY_SEATS_AVAILABLE",
#                 "revenue": "REVENUE",
#                 "speed": null,
#                 "updated_at": "2024-09-14T06:45:28-04:00"
#             },
#             "id": "y1823",
#             "links": {
#                 "self": "/vehicles/y1823"
#             },
#             "relationships": {
#                 "route": {
#                     "data": {
#                         "id": "1",
#                         "type": "route"
#                     }
#                 },
#                 "stop": {
#                     "data": {
#                         "id": "95",
#                         "type": "stop"
#                     }
#                 },
#                 "trip": {
#                     "data": {
#                         "id": "64387624",
#                         "type": "trip"
#                     }
#                 }
#             },
#             "type": "vehicle"
#         },
#         {
#             "attributes": {
#                 "bearing": 341,
#                 "carriages": [],
#                 "current_status": "IN_TRANSIT_TO",
#                 "current_stop_sequence": 15,
#                 "direction_id": 0,
#                 "label": "1788",
#                 "latitude": 42.35493279,
#                 "longitude": -71.091500789,
#                 "occupancy_status": "FEW_SEATS_AVAILABLE",
#                 "revenue": "REVENUE",
#                 "speed": null,
#                 "updated_at": "2024-09-14T06:45:32-04:00"
#             },
#             "id": "y1788",
#             "links": {
#                 "self": "/vehicles/y1788"
#             },
#             "relationships": {
#                 "route": {
#                     "data": {
#                         "id": "1",
#                         "type": "route"
#                     }
#                 },
#                 "stop": {
#                     "data": {
#                         "id": "97",
#                         "type": "stop"
#                     }
#                 },
#                 "trip": {
#                     "data": {
#                         "id": "64387623",
#                         "type": "trip"
#                     }
#                 }
#             },
#             "type": "vehicle"
#         }
#     ],
#     "included": [
#         {
#             "attributes": {
#                 "bikes_allowed": 1,
#                 "block_id": "C01-13",
#                 "direction_id": 0,
#                 "headsign": "Harvard",
#                 "name": "",
#                 "revenue": "REVENUE",
#                 "wheelchair_accessible": 1
#             },
#             "id": "64387623",
#             "links": {
#                 "self": "/trips/64387623"
#             },
#             "relationships": {
#                 "route": {
#                     "data": {
#                         "id": "1",
#                         "type": "route"
#                     }
#                 },
#                 "route_pattern": {
#                     "data": {
#                         "id": "1-_-0",
#                         "type": "route_pattern"
#                     }
#                 },
#                 "service": {
#                     "data": {
#                         "id": "FallSaturday",
#                         "type": "service"
#                     }
#                 },
#                 "shape": {
#                     "data": {
#                         "id": "010128",
#                         "type": "shape"
#                     }
#                 }
#             },
#             "type": "trip"
#         },
#         {
#             "attributes": {
#                 "bikes_allowed": 1,
#                 "block_id": "C01-5",
#                 "direction_id": 0,
#                 "headsign": "Harvard",
#                 "name": "",
#                 "revenue": "REVENUE",
#                 "wheelchair_accessible": 1
#             },
#             "id": "64387624",
#             "links": {
#                 "self": "/trips/64387624"
#             },
#             "relationships": {
#                 "route": {
#                     "data": {
#                         "id": "1",
#                         "type": "route"
#                     }
#                 },
#                 "route_pattern": {
#                     "data": {
#                         "id": "1-_-0",
#                         "type": "route_pattern"
#                     }
#                 },
#                 "service": {
#                     "data": {
#                         "id": "FallSaturday",
#                         "type": "service"
#                     }
#                 },
#                 "shape": {
#                     "data": {
#                         "id": "010128",
#                         "type": "shape"
#                     }
#                 }
#             },
#             "type": "trip"
#         },
#         {
#             "attributes": {
#                 "bikes_allowed": 1,
#                 "block_id": "C01-12",
#                 "direction_id": 0,
#                 "headsign": "Harvard",
#                 "name": "",
#                 "revenue": "REVENUE",
#                 "wheelchair_accessible": 1
#             },
#             "id": "64387626",
#             "links": {
#                 "self": "/trips/64387626"
#             },
#             "relationships": {
#                 "route": {
#                     "data": {
#                         "id": "1",
#                         "type": "route"
#                     }
#                 },
#                 "route_pattern": {
#                     "data": {
#                         "id": "1-_-0",
#                         "type": "route_pattern"
#                     }
#                 },
#                 "service": {
#                     "data": {
#                         "id": "FallSaturday",
#                         "type": "service"
#                     }
#                 },
#                 "shape": {
#                     "data": {
#                         "id": "010128",
#                         "type": "shape"
#                     }
#                 }
#             },
#             "type": "trip"
#         },
#         {
#             "attributes": {
#                 "bikes_allowed": 1,
#                 "block_id": "C01-9",
#                 "direction_id": 1,
#                 "headsign": "Nubian",
#                 "name": "",
#                 "revenue": "REVENUE",
#                 "wheelchair_accessible": 1
#             },
#             "id": "64387714",
#             "links": {
#                 "self": "/trips/64387714"
#             },
#             "relationships": {
#                 "route": {
#                     "data": {
#                         "id": "1",
#                         "type": "route"
#                     }
#                 },
#                 "route_pattern": {
#                     "data": {
#                         "id": "1-_-1",
#                         "type": "route_pattern"
#                     }
#                 },
#                 "service": {
#                     "data": {
#                         "id": "FallSaturday",
#                         "type": "service"
#                     }
#                 },
#                 "shape": {
#                     "data": {
#                         "id": "010136",
#                         "type": "shape"
#                     }
#                 }
#             },
#             "type": "trip"
#         },
#         {
#             "attributes": {
#                 "bikes_allowed": 1,
#                 "block_id": "C01-1",
#                 "direction_id": 1,
#                 "headsign": "Nubian",
#                 "name": "",
#                 "revenue": "REVENUE",
#                 "wheelchair_accessible": 1
#             },
#             "id": "64387718",
#             "links": {
#                 "self": "/trips/64387718"
#             },
#             "relationships": {
#                 "route": {
#                     "data": {
#                         "id": "1",
#                         "type": "route"
#                     }
#                 },
#                 "route_pattern": {
#                     "data": {
#                         "id": "1-_-1",
#                         "type": "route_pattern"
#                     }
#                 },
#                 "service": {
#                     "data": {
#                         "id": "FallSaturday",
#                         "type": "service"
#                     }
#                 },
#                 "shape": {
#                     "data": {
#                         "id": "010136",
#                         "type": "shape"
#                     }
#                 }
#             },
#             "type": "trip"
#         }
#     ],
#     "jsonapi": {
#         "version": "1.0"
#     }
# }

# %% [markdown]
# Use the code below to read the data from your MySQL database and store it in a pandas dataframe.
#
# You you need to install pymysql to run the code:
#
# pip install pymysql

# %%
import os
import pymysql
import pandas as pd

host = '127.0.0.1'
port = '3306'
user = 'root'
password = 'MyNewPass'
password = 'Best3tries!'
database = 'MBTAdb'

conn = pymysql.connect(
    host=host,
    port=int(3306),
    user="root",
    passwd=password,
    db=database,
    charset='utf8mb4')

df = pd.read_sql_query("SELECT * FROM mbta_buses",
    conn)

df.tail(10)
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python311\site-packages\pymysql\connections.py:649, in Connection.connect(self, sock)
#     648 try:
# --> 649     sock = socket.create_connection(
#     650         (self.host, self.port), self.connect_timeout, **kwargs
#     651     )
#     652     break
#
# File C:\ProgramData\anaconda3\Lib\socket.py:851, in create_connection(address, timeout, source_address, all_errors)
#     850 if not all_errors:
# --> 851     raise exceptions[0]
#     852 raise ExceptionGroup("create_connection failed", exceptions)
#
# File C:\ProgramData\anaconda3\Lib\socket.py:836, in create_connection(address, timeout, source_address, all_errors)
#     835     sock.bind(source_address)
# --> 836 sock.connect(sa)
#     837 # Break explicitly a reference cycle
#
# ConnectionRefusedError: [WinError 10061] No connection could be made because the target machine actively refused it
#
# During handling of the above exception, another exception occurred:
#
# OperationalError                          Traceback (most recent call last)
# Cell In[8], line 12
#       9 password = 'Best3tries!'
#      10 database = 'MBTAdb'
# ---> 12 conn = pymysql.connect(
#      13     host=host,
#      14     port=int(3306),
#      15     user="root",
#      16     passwd=password,
#      17     db=database,
#      18     charset='utf8mb4')
#      20 df = pd.read_sql_query("SELECT * FROM mbta_buses",
#      21     conn)
#      23 df.tail(10)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pymysql\connections.py:361, in Connection.__init__(self, user, password, host, database, unix_socket, port, charset, collation, sql_mode, read_default_file, conv, use_unicode, client_flag, cursorclass, init_command, connect_timeout, read_default_group, autocommit, local_infile, max_allowed_packet, defer_connect, auth_plugin_map, read_timeout, write_timeout, bind_address, binary_prefix, program_name, server_public_key, ssl, ssl_ca, ssl_cert, ssl_disabled, ssl_key, ssl_key_password, ssl_verify_cert, ssl_verify_identity, compress, named_pipe, passwd, db)
#     359     self._sock = None
#     360 else:
# --> 361     self.connect()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pymysql\connections.py:716, in Connection.connect(self, sock)
#     714     if DEBUG:
#     715         print(exc.traceback)
# --> 716     raise exc
#     718 # If e is neither DatabaseError or IOError, It's a bug.
#     719 # But raising AssertionError hides original error.
#     720 # So just reraise it.
#     721 raise
#
# OperationalError: (2003, "Can't connect to MySQL server on '127.0.0.1' ([WinError 10061] No connection could be made because the target machine actively refused it)")

# %% [markdown]
# The code below saves the data as a csv file to the local directory as a backup.

# %%
df.to_csv('mbta.csv')

# %% [markdown]
# <h1>What is the average time it takes for a bus to complete the route</h1>

# %% [markdown]
# <h1>Provide a Visualization based on the data</h1>

# %% [markdown]
# <h1>Give an estimate of the speed of the bus from current_stop_sequence = 1 to the last  current_stop_sequence. </h1>
#
# Note: You can use the haversine Python library to calculate the distance between two points, given two longitude and latitude coordinates.
