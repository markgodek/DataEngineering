# %% [markdown]
# <h1>Module 16 Project Template</h1>

# %% [markdown]
# Use the code below to help you analyze the data returned by the MBTA API:

# %%
mbtaURL = "https://api-v3.mbta.com/vehicles?filter[route]=1&include=trip"

import urllib.request, json
with urllib.request.urlopen(mbtaURL) as url:
    data = json.loads(url.read().decode())
   
    with open('data.json', 'w') as outfile:
        json.dump(data, outfile)
   
    with open('data.txt', 'w') as outfile:
        json.dump(json.dumps(data, indent=4, sort_keys=True), outfile)
       
    print(json.dumps(data, indent=4, sort_keys=True))
# Out:
# {
#     "data": [
#         {
#             "attributes": {
#                 "bearing": 310,
#                 "carriages": [],
#                 "current_status": "IN_TRANSIT_TO",
#                 "current_stop_sequence": 18,
#                 "direction_id": 0,
#                 "label": "1877",
#                 "latitude": 42.365040989,
#                 "longitude": -71.10296769,
#                 "occupancy_status": "MANY_SEATS_AVAILABLE",
#                 "revenue": "REVENUE",
#                 "speed": null,
#                 "updated_at": "2024-09-14T07:20:47-04:00"
#             },
#             "id": "y1877",
#             "links": {
#                 "self": "/vehicles/y1877"
#             },
#             "relationships": {
#                 "route": {
#                     "data": {
#                         "id": "1",
#                         "type": "route"
#                     }
#                 },
#                 "stop": {
#                     "data": {
#                         "id": "102",
#                         "type": "stop"
#                     }
#                 },
#                 "trip": {
#                     "data": {
#                         "id": "64387626",
#                         "type": "trip"
#                     }
#                 }
#             },
#             "type": "vehicle"
#         },
#         {
#             "attributes": {
#                 "bearing": 309,
#                 "carriages": [],
#                 "current_status": "IN_TRANSIT_TO",
#                 "current_stop_sequence": 18,
#                 "direction_id": 0,
#                 "label": "1872",
#                 "latitude": 42.364597539,
#                 "longitude": -71.102088929,
#                 "occupancy_status": "MANY_SEATS_AVAILABLE",
#                 "revenue": "REVENUE",
#                 "speed": null,
#                 "updated_at": "2024-09-14T07:20:45-04:00"
#             },
#             "id": "y1872",
#             "links": {
#                 "self": "/vehicles/y1872"
#             },
#             "relationships": {
#                 "route": {
#                     "data": {
#                         "id": "1",
#                         "type": "route"
#                     }
#                 },
#                 "stop": {
#                     "data": {
#                         "id": "102",
#                         "type": "stop"
#                     }
#                 },
#                 "trip": {
#                     "data": {
#                         "id": "64387625",
#                         "type": "trip"
#                     }
#                 }
#             },
#             "type": "vehicle"
#         },
#         {
#             "attributes": {
#                 "bearing": 116,
#                 "carriages": [],
#                 "current_status": "IN_TRANSIT_TO",
#                 "current_stop_sequence": 4,
#                 "direction_id": 0,
#                 "label": "1847",
#                 "latitude": 42.33218869,
#                 "longitude": -71.07964652,
#                 "occupancy_status": "MANY_SEATS_AVAILABLE",
#                 "revenue": "REVENUE",
#                 "speed": null,
#                 "updated_at": "2024-09-14T07:20:42-04:00"
#             },
#             "id": "y1847",
#             "links": {
#                 "self": "/vehicles/y1847"
#             },
#             "relationships": {
#                 "route": {
#                     "data": {
#                         "id": "1",
#                         "type": "route"
#                     }
#                 },
#                 "stop": {
#                     "data": {
#                         "id": "6",
#                         "type": "stop"
#                     }
#                 },
#                 "trip": {
#                     "data": {
#                         "id": "64387627",
#                         "type": "trip"
#                     }
#                 }
#             },
#             "type": "vehicle"
#         },
#         {
#             "attributes": {
#                 "bearing": 165,
#                 "carriages": [],
#                 "current_status": "STOPPED_AT",
#                 "current_stop_sequence": 11,
#                 "direction_id": 1,
#                 "label": "1823",
#                 "latitude": 42.34992528,
#                 "longitude": -71.0890418,
#                 "occupancy_status": "MANY_SEATS_AVAILABLE",
#                 "revenue": "REVENUE",
#                 "speed": null,
#                 "updated_at": "2024-09-14T07:20:45-04:00"
#             },
#             "id": "y1823",
#             "links": {
#                 "self": "/vehicles/y1823"
#             },
#             "relationships": {
#                 "route": {
#                     "data": {
#                         "id": "1",
#                         "type": "route"
#                     }
#                 },
#                 "stop": {
#                     "data": {
#                         "id": "77",
#                         "type": "stop"
#                     }
#                 },
#                 "trip": {
#                     "data": {
#                         "id": "64387722",
#                         "type": "trip"
#                     }
#                 }
#             },
#             "type": "vehicle"
#         },
#         {
#             "attributes": {
#                 "bearing": 129,
#                 "carriages": [],
#                 "current_status": "IN_TRANSIT_TO",
#                 "current_stop_sequence": 16,
#                 "direction_id": 1,
#                 "label": "1788",
#                 "latitude": 42.34065526,
#                 "longitude": -71.081677679,
#                 "occupancy_status": "MANY_SEATS_AVAILABLE",
#                 "revenue": "REVENUE",
#                 "speed": null,
#                 "updated_at": "2024-09-14T07:20:46-04:00"
#             },
#             "id": "y1788",
#             "links": {
#                 "self": "/vehicles/y1788"
#             },
#             "relationships": {
#                 "route": {
#                     "data": {
#                         "id": "1",
#                         "type": "route"
#                     }
#                 },
#                 "stop": {
#                     "data": {
#                         "id": "84",
#                         "type": "stop"
#                     }
#                 },
#                 "trip": {
#                     "data": {
#                         "id": "64387721",
#                         "type": "trip"
#                     }
#                 }
#             },
#             "type": "vehicle"
#         }
#     ],
#     "included": [
#         {
#             "attributes": {
#                 "bikes_allowed": 1,
#                 "block_id": "C01-9",
#                 "direction_id": 0,
#                 "headsign": "Harvard",
#                 "name": "",
#                 "revenue": "REVENUE",
#                 "wheelchair_accessible": 1
#             },
#             "id": "64387625",
#             "links": {
#                 "self": "/trips/64387625"
#             },
#             "relationships": {
#                 "route": {
#                     "data": {
#                         "id": "1",
#                         "type": "route"
#                     }
#                 },
#                 "route_pattern": {
#                     "data": {
#                         "id": "1-_-0",
#                         "type": "route_pattern"
#                     }
#                 },
#                 "service": {
#                     "data": {
#                         "id": "FallSaturday",
#                         "type": "service"
#                     }
#                 },
#                 "shape": {
#                     "data": {
#                         "id": "010128",
#                         "type": "shape"
#                     }
#                 }
#             },
#             "type": "trip"
#         },
#         {
#             "attributes": {
#                 "bikes_allowed": 1,
#                 "block_id": "C01-12",
#                 "direction_id": 0,
#                 "headsign": "Harvard",
#                 "name": "",
#                 "revenue": "REVENUE",
#                 "wheelchair_accessible": 1
#             },
#             "id": "64387626",
#             "links": {
#                 "self": "/trips/64387626"
#             },
#             "relationships": {
#                 "route": {
#                     "data": {
#                         "id": "1",
#                         "type": "route"
#                     }
#                 },
#                 "route_pattern": {
#                     "data": {
#                         "id": "1-_-0",
#                         "type": "route_pattern"
#                     }
#                 },
#                 "service": {
#                     "data": {
#                         "id": "FallSaturday",
#                         "type": "service"
#                     }
#                 },
#                 "shape": {
#                     "data": {
#                         "id": "010128",
#                         "type": "shape"
#                     }
#                 }
#             },
#             "type": "trip"
#         },
#         {
#             "attributes": {
#                 "bikes_allowed": 1,
#                 "block_id": "C22-83",
#                 "direction_id": 0,
#                 "headsign": "Harvard",
#                 "name": "",
#                 "revenue": "REVENUE",
#                 "wheelchair_accessible": 1
#             },
#             "id": "64387627",
#             "links": {
#                 "self": "/trips/64387627"
#             },
#             "relationships": {
#                 "route": {
#                     "data": {
#                         "id": "1",
#                         "type": "route"
#                     }
#                 },
#                 "route_pattern": {
#                     "data": {
#                         "id": "1-_-0",
#                         "type": "route_pattern"
#                     }
#                 },
#                 "service": {
#                     "data": {
#                         "id": "FallSaturday",
#                         "type": "service"
#                     }
#                 },
#                 "shape": {
#                     "data": {
#                         "id": "010128",
#                         "type": "shape"
#                     }
#                 }
#             },
#             "type": "trip"
#         },
#         {
#             "attributes": {
#                 "bikes_allowed": 1,
#                 "block_id": "C01-13",
#                 "direction_id": 1,
#                 "headsign": "Nubian",
#                 "name": "",
#                 "revenue": "REVENUE",
#                 "wheelchair_accessible": 1
#             },
#             "id": "64387721",
#             "links": {
#                 "self": "/trips/64387721"
#             },
#             "relationships": {
#                 "route": {
#                     "data": {
#                         "id": "1",
#                         "type": "route"
#                     }
#                 },
#                 "route_pattern": {
#                     "data": {
#                         "id": "1-_-1",
#                         "type": "route_pattern"
#                     }
#                 },
#                 "service": {
#                     "data": {
#                         "id": "FallSaturday",
#                         "type": "service"
#                     }
#                 },
#                 "shape": {
#                     "data": {
#                         "id": "010136",
#                         "type": "shape"
#                     }
#                 }
#             },
#             "type": "trip"
#         },
#         {
#             "attributes": {
#                 "bikes_allowed": 1,
#                 "block_id": "C01-5",
#                 "direction_id": 1,
#                 "headsign": "Nubian",
#                 "name": "",
#                 "revenue": "REVENUE",
#                 "wheelchair_accessible": 1
#             },
#             "id": "64387722",
#             "links": {
#                 "self": "/trips/64387722"
#             },
#             "relationships": {
#                 "route": {
#                     "data": {
#                         "id": "1",
#                         "type": "route"
#                     }
#                 },
#                 "route_pattern": {
#                     "data": {
#                         "id": "1-_-1",
#                         "type": "route_pattern"
#                     }
#                 },
#                 "service": {
#                     "data": {
#                         "id": "FallSaturday",
#                         "type": "service"
#                     }
#                 },
#                 "shape": {
#                     "data": {
#                         "id": "010136",
#                         "type": "shape"
#                     }
#                 }
#             },
#             "type": "trip"
#         }
#     ],
#     "jsonapi": {
#         "version": "1.0"
#     }
# }

# %% [markdown]
# Use the code below to read the data from your MySQL database and store it in a pandas dataframe.
#
# You you need to install pymysql to run the code:
#
# pip install pymysql

# %%
import os
import pymysql
import pandas as pd

host = '127.0.0.1'
port = '3306'
user = 'root'
password = 'MyNewPass'
database = 'MBTAdb'

conn = pymysql.connect(
    host=host,
    port=int(3306),
    user="root",
    passwd=password,
    db=database,
    charset='utf8mb4')

df = pd.read_sql_query("SELECT * FROM mbta_buses",
    conn)

df.tail(10)
# Out:
# C:\Users\markg\AppData\Local\Temp\ipykernel_20772\2324256652.py:19: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query("SELECT * FROM mbta_buses",
# Empty DataFrame
# Columns: [record_num, id, latitude, longitude, direction, current_status, label, occupancy_status, speed, updated_at]
# Index: []

# %% [markdown]
# The code below saves the data as a csv file to the local directory as a backup.

# %%
df.to_csv('mbta.csv')

# %% [markdown]
# <h1>What is the average time it takes for a bus to complete the route</h1>

# %% [markdown]
# <h1>Provide a Visualization based on the data</h1>

# %% [markdown]
# <h1>Give an estimate of the speed of the bus from current_stop_sequence = 1 to the last  current_stop_sequence. </h1>
#
# Note: You can use the haversine Python library to calculate the distance between two points, given two longitude and latitude coordinates.
